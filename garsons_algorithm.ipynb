# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from plink_datasets import *
from ANN_MCC import *
from NID_fast import *
import sys
import sklearn.metrics as metrics
import scikitplot as skplt
import torch.nn.utils.prune as prune

# %%
model = torch.load("/home/kasper/Phenotype_prediction/models/main_effects_mlpm.pth")
print(model)
# Out:
# ANN(
#   (neural_network): Sequential(
#     (0): Linear(in_features=2934, out_features=500, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.01, inplace=False)
#     (3): Linear(in_features=500, out_features=400, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.01, inplace=False)
#     (6): Linear(in_features=400, out_features=300, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.01, inplace=False)
#     (9): Linear(in_features=300, out_features=200, bias=True)
#     (10): ReLU()
#     (11): Dropout(p=0.01, inplace=False)
#     (12): Linear(in_features=200, out_features=100, bias=True)
#     (13): ReLU()
#     (14): Dropout(p=0.01, inplace=False)
#     (15): Linear(in_features=100, out_features=1, bias=True)
#   )
#   (uni_0): Sequential(
#     (0): Linear(in_features=1, out_features=10, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.01, inplace=False)
#     (3): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (uni_1): Sequential(
# ...

# %%
model_weights = get_weights(model)
w_input, w_later = preprocess_weights(model_weights)
main_effects = get_nlargest(generator = garsons_algorithm(w_input, w_later), N = 10000)
main_effect_pd = pd.DataFrame(main_effects, columns=["Index", "Importance"])
main_effect_pd.to_csv("/home/kasper/Phenotype_prediction/results/main_effects_garson_mlpm.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2934/2934 [00:00<00:00, 21971.86it/s]
